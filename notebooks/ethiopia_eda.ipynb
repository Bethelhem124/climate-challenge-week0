# %% [markdown]
# Importing dependencies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# Load CSV

# %%
df = pd.read_csv("../data/ethiopia.csv", encoding='latin1', skiprows=[1])
print(df.shape)
df.head()
# Out:
# (4107, 12)
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    2  12.30    24.01     4.09      19.92          0.0  33.29  2.39
# 1  2015    3  12.49    24.17     3.97      20.20          0.0  33.83  1.77
# 2  2015    4  14.08    23.78     6.90      16.88          0.0  38.84  0.87
# 3  2015    5  14.06    23.15     7.32      15.83          0.0  47.07  1.34
# 4  2015    6  14.26    23.45     7.44      16.01          0.0  58.20  1.70
#
#    WS2M_MAX     PS  QV2M
# 0      4.19  77.14  3.35
# 1      2.76  77.11  3.43
# 2      1.28  77.07  4.60
# 3      2.14  77.01  5.58
# 4      2.75  77.07  6.95

# %% [markdown]
# Add country column

# %%
df["Country"] = "Ethiopia"

# %% [markdown]
# Convert YEAR + DOY → Date

# %%
df["Date"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")

# %% [markdown]
# Extract Month

# %%
df["Month"] = df["Date"].dt.month

# %% [markdown]
# Data cleaning and summary statistics

# %%
df.replace(-999, np.nan, inplace=True)
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    2  12.30    24.01     4.09      19.92         0.00  33.29  2.39
# 1     2015    3  12.49    24.17     3.97      20.20         0.00  33.83  1.77
# 2     2015    4  14.08    23.78     6.90      16.88         0.00  38.84  0.87
# 3     2015    5  14.06    23.15     7.32      15.83         0.00  47.07  1.34
# 4     2015    6  14.26    23.45     7.44      16.01         0.00  58.20  1.70
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4102  2026   86  16.99    24.29    11.80      12.49         5.27  73.87  1.79
# 4103  2026   87  15.29    19.58    12.08       7.50         6.46  80.85  1.13
# 4104  2026   88  16.28    22.34    11.69      10.65         9.53  77.96  1.30
# 4105  2026   89  17.66    25.31    11.08      14.23         0.85  68.88  2.02
# 4106  2026   90  18.25    26.36    12.14      14.22         0.40  63.95  2.18
#
#       WS2M_MAX     PS   QV2M
# 0         4.19  77.14   3.35
# 1         2.76  77.11   3.43
# 2         1.28  77.07   4.60
# 3         2.14  77.01   5.58
# 4         2.75  77.07   6.95
# ...        ...    ...    ...
# 4102      3.09  76.60  11.17
# 4103      2.35  76.59  11.29
# 4104      2.39  76.48  11.42
# 4105      3.80  76.44  10.64
# 4106      3.64  76.47  10.14
#
# [4107 rows x 12 columns]

# %%
df["Month"] = df["Date"].dt.month

# %%
df[["Date", "Month"]].head()
# Out:
#         Date  Month
# 0 2015-01-02      1
# 1 2015-01-03      1
# 2 2015-01-04      1
# 3 2015-01-05      1
# 4 2015-01-06      1

# %%
dup_count = df.duplicated().sum()
print("Duplicate rows:", dup_count)
# Out:
# Duplicate rows: 0

# %% [markdown]
# Duplicate rows
#
# No duplicate rows were found in the dataset (0 duplicates).
# This indicates that each observation is unique, and no data cleaning was required for duplicates.

# %%
df.describe()
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4107.000000  4107.000000  4107.000000  4107.000000  4107.000000
# mean   2020.132700   180.164841    16.069557    23.199284    10.229196
# std       3.248315   106.270943     1.897073     2.751797     2.605421
# min    2015.000000     1.000000    10.030000    15.650000     1.170000
# 25%    2017.000000    86.000000    14.820000    21.110000     8.425000
# 50%    2020.000000   179.000000    16.040000    22.740000    10.990000
# 75%    2023.000000   272.000000    17.360000    25.170000    12.220000
# max    2026.000000   366.000000    21.530000    30.930000    15.680000
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4107.000000  4107.000000  4107.000000  4107.000000  4107.000000
# mean     12.970088     3.634680    68.415069     1.979815     3.574882
# std       3.820423     6.289571    14.731775     0.689077     1.123615
# min       3.560000     0.000000    14.420000     0.460000     0.790000
# 25%       9.830000     0.020000    59.050000     1.405000     2.720000
# 50%      13.030000     0.820000    71.120000     1.970000     3.530000
# 75%      16.015000     4.580000    80.805000     2.480000     4.370000
# max      23.240000    82.300000    91.930000     4.130000     7.490000
#
#                 PS         QV2M
# count  4107.000000  4107.000000
# mean     77.037507     9.699111
# std       0.099486     2.361076
# min      76.360000     2.120000
# 25%      76.980000     8.070000
# 50%      77.040000    10.270000
# 75%      77.100000    11.710000
# max      77.370000    13.520000

# %% [markdown]
# Missing values count

# %%
missing_counts = df.isna().sum()
missing_counts
# Out:
# YEAR           0
# DOY            0
# T2M            0
# T2M_MAX        0
# T2M_MIN        0
# T2M_RANGE      0
# PRECTOTCORR    0
# RH2M           0
# WS2M           0
# WS2M_MAX       0
# PS             0
# QV2M           0
# dtype: int64

# %% [markdown]
# Missing percentage

# %%
missing_percent = (df.isna().sum() / len(df)) * 100
missing_percent
# Out:
# YEAR           0.0
# DOY            0.0
# T2M            0.0
# T2M_MAX        0.0
# T2M_MIN        0.0
# T2M_RANGE      0.0
# PRECTOTCORR    0.0
# RH2M           0.0
# WS2M           0.0
# WS2M_MAX       0.0
# PS             0.0
# QV2M           0.0
# dtype: float64

# %%
missing_percent[missing_percent > 5]
# Out:
# Series([], dtype: float64)

# %% [markdown]
# Missing values analysis
# After replacing sentinel values (-999) with NaN, the dataset was checked for missing values.
#
# No column has more than 5% missing data. This indicates that the dataset is relatively complete and suitable for analysis without significant data loss.
#
# Minor missing values (if any) are unlikely to significantly affect the overall results.

# %% [markdown]
# ●	Outlier Detection & Basic Cleaning

# %% [markdown]
# compute Z-scores

# %%
from scipy.stats import zscore

cols = ["T2M", "T2M_MAX", "T2M_MIN", "PRECTOTCORR", "RH2M", "WS2M", "WS2M_MAX"]

z_scores = np.abs(zscore(df[cols], nan_policy='omit'))

outliers = (z_scores > 3).any(axis=1)
outlier_count = outliers.sum()

outlier_count
# Out:
# np.int64(132)

# %% [markdown]
# Outlier detection & handling decision
#
# Outliers were identified using the Z-score method, where any observation with |Z| > 3 was considered an outlier.
#
# A total of **132 rows** were flagged as outliers across the selected climate variables.
#
# This indicates the presence of extreme values in the dataset, which may correspond to real-world climate events.
# In climate datasets, extreme values are often meaningful and represent actual environmental phenomena such as extreme temperatures, storms, or unusual weather conditions. Removing these values could lead to loss of important information and bias the analysis.
#
# Therefore, all outlier observations were preserved for further analysis.

# %%
df[cols] = df[cols].ffill()

# %%
threshold = int(df.shape[1] * 0.7)
df = df.dropna(thresh=threshold)

# %%
df.to_csv("../data/ethiopia_clean.csv", index=False)

# %% [markdown]
# ●	Time Series Analysis

# %% [markdown]
# Monthly Average Temperature

# %%
monthly_temp = df.groupby("Month")["T2M"].mean()

import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
monthly_temp.plot()
plt.title("Monthly Average Temperature")
plt.show()

# %% [markdown]
# # Temperature trend
# The plot shows monthly average temperature patterns. Warmer months appear around (X), while cooler months occur around (Y).

# %% [markdown]
# Rainfall bar chart

# %%
monthly_rain = df.groupby("Month")["PRECTOTCORR"].sum()

plt.figure(figsize=(10,5))
monthly_rain.plot(kind="bar")
plt.title("Monthly Total Rainfall")
plt.show()

# %% [markdown]
# # Rainfall Patterns
#
# Rainfall peaks during (X months), indicating the rainy season.

# %% [markdown]
# ●	Correlation & Relationship Analysis

# %% [markdown]
# Heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# Scatter Plots

# %%
sns.scatterplot(data=df, x="T2M", y="RH2M")
plt.show()

df["T2M_RANGE"] = df["T2M_MAX"] - df["T2M_MIN"]

sns.scatterplot(data=df, x="T2M_RANGE", y="WS2M")
plt.show()

# %% [markdown]
# # Scatter Plot Interpretations
# T2M vs. RH2M: Shows a weak negative correlation. As temperature ($T2M$) increases, relative humidity ($RH2M$) generally tends to decrease, though the high density of points suggests many other factors are at play.
#
# T2M_RANGE vs. WS2M: Shows a weak positive correlation. A wider daily temperature range often coincides with slightly higher wind speeds, likely due to increased thermal turbulence.

# %% [markdown]
# # Three Strongest Potential Correlations
# T2M & T2M_MAX/MIN (Strong Positive): Average temperature is mathematically and physically tied to its daily highs and lows.
#
# T2M_RANGE & RH2M (Strong Negative): High temperature swings typically occur in dry environments (low humidity) where the air loses heat quickly at night.
#
# PRECTOTCORR & RH2M (Moderate Positive): High precipitation is almost always coupled with high humidity levels.

# %% [markdown]
# # Distribution Analysis

# %% [markdown]
# Histogram

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["PRECTOTCORR"], kde=True)
plt.show()

# %% [markdown]
# Histogram Analysis
#
# Distribution Shape: The data is heavily right-skewed. The vast majority of observations are at or near zero (dry days), with a long "tail" representing rare, high-precipitation events.

# %% [markdown]
# Bubble Chart

# %%
plt.figure(figsize=(8,6))
plt.scatter(df["T2M"], df["RH2M"], s=df["PRECTOTCORR"]*10, alpha=0.5)
plt.xlabel("T2M")
plt.ylabel("RH2M")
plt.title("Bubble Chart")
plt.show()
